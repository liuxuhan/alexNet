# %%
import pandas as pd

# %%
all = pd.read_csv('all.csv')

# %%
all = all[all["category"].isin([0,1,2,3])]

# %%
all = all.sample(frac=1).reset_index(drop=True)
print(int(all.shape[0]*0.8),all.shape[0])
# Out:
# 1175 1469

# %%
train = all.iloc[:1175,:]
val = all.iloc[1175:,:]

# %%
train.shape
# Out:
# (1175, 2)

# %%
val.shape
# Out:
# (294, 2)

# %%
train.to_csv("train_4.csv",index=False)
val.to_csv("val_4.csv",index=False)

# %%
test = pd.read_csv("train.csv")
test['category'].tolist()
# Out:
# [61,
#  72,
#  10,
#  125,
#  69,
#  2,
#  35,
#  61,
#  42,
#  62,
#  12,
#  109,
#  26,
#  1,
#  107,
#  92,
#  78,
#  128,
#  80,
#  68,
#  109,
#  102,
#  97,
#  16,
#  113,
#  90,
#  123,
#  8,
#  101,
#  90,
#  83,
#  56,
#  23,
#  1,
#  36,
#  127,
#  59,
#  56,
#  32,
#  97,
#  35,
#  62,
#  81,
#  47,
#  52,
#  108,
#  43,
#  60,
#  119,
#  97,
#  91,
#  52,
#  75,
#  70,
#  26,
#  61,
#  65,
#  83,
#  94,
#  89,
#  67,
#  120,
#  50,
#  78,
#  15,
#  49,
#  12,
#  62,
#  127,
#  98,
#  40,
#  108,
#  119,
#  23,
#  93,
#  19,
#  97,
#  1,
#  22,
#  92,
#  112,
#  79,
#  108,
#  23,
#  116,
#  128,
#  34,
#  100,
#  78,
#  87,
#  15,
#  120,
#  65,
#  39,
#  63,
#  32,
#  42,
#  47,
#  36,
#  3,
#  102,
#  9,
#  72,
#  110,
#  60,
#  66,
#  116,
#  128,
#  48,
#  102,
#  48,
#  125,
#  25,
#  103,
#  129,
#  38,
#  100,
#  120,
#  108,
#  85,
#  72,
#  1,
#  92,
#  123,
#  32,
#  99,
#  20,
#  9,
#  27,
#  118,
#  48,
#  15,
#  16,
#  115,
#  35,
#  47,
#  11,
#  106,
# ...
